# %% [markdown]
# <a href="https://colab.research.google.com/github/wallacemw/DeepSeek-Coder/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import xgboost as xgb
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Carregar dados e treinar um modelo
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2)

modelo = xgb.XGBClassifier()
modelo.fit(X_train, y_train)

# Salvar modelo treinado
modelo.save_model("modelo_xgb.bin")
